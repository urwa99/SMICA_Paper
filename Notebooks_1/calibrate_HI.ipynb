# %%
import healpy as hp
import matplotlib.pyplot as plt
import numpy as np
# uses the CAMB cosmology which produced the cls
import camb
from cosmology import Cosmology
import glass
import glass.ext.camb
from astropy.constants import M_sun

# %%
nside=256
freqs=np.arange(1042,1183,step=1) #instead of steps of1MHz use 10
nfreqs=len(freqs)
lmax=3*nside -1

# # creating a numpy random number generator for sampling
# rng = np.random.default_rng(seed=42)

# cosmology for the simulation (matches simulated_fgds.ipynb / gridimp_cartesian_cube.ipynb: H0=70, Om0=0.30)
h = 0.7
Oc = 0.25
Ob = 0.05
rho_HI= 5.46e7 #h_70 M_sun Mpc^-3
print(rho_HI)
# set up CAMB parameters for matter angular power spectrum
pars = camb.set_params(
    H0=100 * h,
    omch2=Oc * h**2,
    ombh2=Ob * h**2,
    # ns=0.96,
    # As=2.1e-9,
    NonLinear=camb.model.NonLinear_both,
)
# Out:
# 54600000.0

# %%
freqs[0]
# Out:
# np.int64(1042)

# %%
z_f= (1420/freqs[0])-1
z_i= (1420/freqs[-1])-1
# set up the redshift range
# z = np.linspace(z_i, z_f, nfreqs)
print(z_i, z_f)
# Out:
# 0.20135363790186123 0.36276391554702503

# %%
def compute_matter_cls(z_i:float, z_f: float, nfreq: int, lmax:int):
    """
    Compute the matter angular power spectrum using CAMB without correlations between shells.
    
    Parameters:
    z_i (float): Initial redshift.
    z_f (float): Final redshift.
    nfreqs (int): Number of frequency channels.
    lmax (int): Maximum multipole.
    
    Returns:
    cls: Angular power spectrum
    """
    zb=glass.redshift_grid(z_i, z_f, num=nfreq)

    # triangular radial windows, equivalent to linear interpolation of n(z)
    shells = glass.linear_windows(zb, dz=0.1*(z_f-z_i)/nfreq)
    
    cl_diag = np.zeros((nfreqs, nfreqs, lmax + 1))

    for i in range(nfreqs-1):
        # Compute angular power spectrum from just one shell
        print ("processing spectra %d" % i)
        cls_i = glass.ext.camb.matter_cls(pars, lmax, [shells[i]])
        cl_diag[i, i,:] = cls_i[0]  # This is Cl^i
    
    return shells, cl_diag

# %%
def compute_matter_cls_ii(z_i:float, z_f: float, nfreq: int, lmax:int):
    """
    Compute the matter angular power spectrum using CAMB without correlations between shells.
    
    Parameters:
    z_i (float): Initial redshift.
    z_f (float): Final redshift.
    nfreqs (int): Number of frequency channels.
    lmax (int): Maximum multipole.
    
    Returns:
    cls: Angular power spectrum
    """
    zb=glass.redshift_grid(z_i, z_f, num=nfreq)

    # triangular radial windows, equivalent to linear interpolation of n(z)
    shells = glass.linear_windows(zb, dz=0.1*(z_f-z_i)/nfreq)
    
    cl_diag = np.zeros((nfreqs, lmax + 1))

    for i in range(nfreqs-1):
        # Compute angular power spectrum from just one shell
        print ("processing spectra %d" % i)
        cls_i = glass.ext.camb.matter_cls(pars, lmax, [shells[i]])
        cl_diag[i, :] = cls_i[0]  # This is Cl^i
    
    return shells, cl_diag

# %%
def compute_matter_cls_corr(z_i:float, z_f: float, nfreq: int, lmax:int):
    """
    Compute the matter angular power spectrum using CAMB with correlations between shells.
    
    Parameters:
    z_i (float): Initial redshift.
    z_f (float): Final redshift.
    nfreqs (int): Number of frequency channels.
    lmax (int): Maximum multipole.
    
    Returns:
    cls: Angular power spectrum
    """
    zb=glass.redshift_grid(z_i, z_f, num=nfreq)

    # triangular radial windows, equivalent to linear interpolation of n(z)
    shells = glass.linear_windows(zb, dz=0.1*(z_f-z_i)/nfreq)
    
    # compute angular matter power spectra with CAMB
    cls = glass.ext.camb.matter_cls(pars, lmax, shells)
    
    return shells, cls

# %%
shells_ii, cls_hi_i=compute_matter_cls_ii(z_i,z_f, nfreqs, lmax)
# Out:
# /tmp/ipykernel_1369273/1825250799.py:17: UserWarning: first triangular window does not start at z=0
#   shells = glass.linear_windows(zb, dz=0.1*(z_f-z_i)/nfreq)
# processing spectra 0
# processing spectra 1
# processing spectra 2
# processing spectra 3
# processing spectra 4
# processing spectra 5
# processing spectra 6
# processing spectra 7
# processing spectra 8
# processing spectra 9
# processing spectra 10
# processing spectra 11
# processing spectra 12
# processing spectra 13
# processing spectra 14
# processing spectra 15
# processing spectra 16
# processing spectra 17
# processing spectra 18
# processing spectra 19
# processing spectra 20
# processing spectra 21
# processing spectra 22
# processing spectra 23
# processing spectra 24
# processing spectra 25
# processing spectra 26
# processing spectra 27
# processing spectra 28
# processing spectra 29
# processing spectra 30
# processing spectra 31
# processing spectra 32
# processing spectra 33
# processing spectra 34
# processing spectra 35
# processing spectra 36
# processing spectra 37
# processing spectra 38
# processing spectra 39
# processing spectra 40
# processing spectra 41
# processing spectra 42
# processing spectra 43
# processing spectra 44
# processing spectra 45
# processing spectra 46
# processing spectra 47
# processing spectra 48
# processing spectra 49
# processing spectra 50
# processing spectra 51
# processing spectra 52
# processing spectra 53
# processing spectra 54
# processing spectra 55
# processing spectra 56
# processing spectra 57
# processing spectra 58
# processing spectra 59
# processing spectra 60
# processing spectra 61
# processing spectra 62
# processing spectra 63
# processing spectra 64
# processing spectra 65
# processing spectra 66
# processing spectra 67
# processing spectra 68
# processing spectra 69
# processing spectra 70
# processing spectra 71
# processing spectra 72
# processing spectra 73
# processing spectra 74
# processing spectra 75
# processing spectra 76
# processing spectra 77
# processing spectra 78
# processing spectra 79
# processing spectra 80
# processing spectra 81
# processing spectra 82
# processing spectra 83
# processing spectra 84
# processing spectra 85
# processing spectra 86
# processing spectra 87
# processing spectra 88
# processing spectra 89
# processing spectra 90
# processing spectra 91
# processing spectra 92
# processing spectra 93
# processing spectra 94
# processing spectra 95
# processing spectra 96
# processing spectra 97
# processing spectra 98
# processing spectra 99
# processing spectra 100
# processing spectra 101
# processing spectra 102
# processing spectra 103
# processing spectra 104
# processing spectra 105
# processing spectra 106
# processing spectra 107
# processing spectra 108
# processing spectra 109
# processing spectra 110
# processing spectra 111
# processing spectra 112
# processing spectra 113
# processing spectra 114
# processing spectra 115
# processing spectra 116
# processing spectra 117
# processing spectra 118
# processing spectra 119
# processing spectra 120
# processing spectra 121
# processing spectra 122
# processing spectra 123
# processing spectra 124
# processing spectra 125
# processing spectra 126
# processing spectra 127
# processing spectra 128
# processing spectra 129
# processing spectra 130
# processing spectra 131
# processing spectra 132
# processing spectra 133
# processing spectra 134
# processing spectra 135
# processing spectra 136
# processing spectra 137
# processing spectra 138
# processing spectra 139

# %%
shells_i, cls_hi=compute_matter_cls(z_i,z_f, nfreqs, lmax)
print(len(cls_hi))
# Out:
# /tmp/ipykernel_1369273/3660055063.py:17: UserWarning: first triangular window does not start at z=0
#   shells = glass.linear_windows(zb, dz=0.1*(z_f-z_i)/nfreq)
# processing spectra 0
# processing spectra 1
# processing spectra 2
# processing spectra 3
# processing spectra 4
# processing spectra 5
# processing spectra 6
# processing spectra 7
# processing spectra 8
# processing spectra 9
# processing spectra 10
# processing spectra 11
# processing spectra 12
# processing spectra 13
# processing spectra 14
# processing spectra 15
# processing spectra 16
# processing spectra 17
# processing spectra 18
# processing spectra 19
# processing spectra 20
# processing spectra 21
# processing spectra 22
# processing spectra 23
# processing spectra 24
# processing spectra 25
# processing spectra 26
# processing spectra 27
# processing spectra 28
# processing spectra 29
# processing spectra 30
# processing spectra 31
# processing spectra 32
# processing spectra 33
# processing spectra 34
# processing spectra 35
# processing spectra 36
# processing spectra 37
# processing spectra 38
# processing spectra 39
# processing spectra 40
# processing spectra 41
# processing spectra 42
# processing spectra 43
# processing spectra 44
# processing spectra 45
# processing spectra 46
# processing spectra 47
# processing spectra 48
# processing spectra 49
# processing spectra 50
# processing spectra 51
# processing spectra 52
# processing spectra 53
# processing spectra 54
# processing spectra 55
# processing spectra 56
# processing spectra 57
# processing spectra 58
# processing spectra 59
# processing spectra 60
# processing spectra 61
# processing spectra 62
# processing spectra 63
# processing spectra 64
# processing spectra 65
# processing spectra 66
# processing spectra 67
# processing spectra 68
# processing spectra 69
# processing spectra 70
# processing spectra 71
# processing spectra 72
# processing spectra 73
# processing spectra 74
# processing spectra 75
# processing spectra 76
# processing spectra 77
# processing spectra 78
# processing spectra 79
# processing spectra 80
# processing spectra 81
# processing spectra 82
# processing spectra 83
# processing spectra 84
# processing spectra 85
# processing spectra 86
# processing spectra 87
# processing spectra 88
# processing spectra 89
# processing spectra 90
# processing spectra 91
# processing spectra 92
# processing spectra 93
# processing spectra 94
# processing spectra 95
# processing spectra 96
# processing spectra 97
# processing spectra 98
# processing spectra 99
# processing spectra 100
# processing spectra 101
# processing spectra 102
# processing spectra 103
# processing spectra 104
# processing spectra 105
# processing spectra 106
# processing spectra 107
# processing spectra 108
# processing spectra 109
# processing spectra 110
# processing spectra 111
# processing spectra 112
# processing spectra 113
# processing spectra 114
# processing spectra 115
# processing spectra 116
# processing spectra 117
# processing spectra 118
# processing spectra 119
# processing spectra 120
# processing spectra 121
# processing spectra 122
# processing spectra 123
# processing spectra 124
# processing spectra 125
# processing spectra 126
# processing spectra 127
# processing spectra 128
# processing spectra 129
# processing spectra 130
# processing spectra 131
# processing spectra 132
# processing spectra 133
# processing spectra 134
# processing spectra 135
# processing spectra 136
# processing spectra 137
# processing spectra 138
# processing spectra 139
# 141

# %%
# cls_healpix=glass.glass_to_healpix_spectra(cls_hi)

# %%
# idx= glass.spectra_indices(len(shells_i))
# x,y=idx[5]
# print(x)
# print(y)
# print(len(idx))

# %%
# # Initialize the array to store the full spectra
# cls_full = np.zeros((nfreqs, nfreqs, lmax + 1))

# # Loop over index pairs (i, j)
# for pair in idx:
#     i, j = pair  # unpack the pair
#     cl_ij = glass.getcl(cls_healpix, i, j)  # get the C_l^{ij} spectrum
#     cls_full[i, j, :] = cl_ij
#     if i != j:
#         cls_full[j, i, :] = cl_ij  # fill the symmetric entry

# print(cls_full.shape) #C_l{ij} in GLASS ordering

# %%
# hi_full = np.zeros((lmax+1, nfreqs, nfreqs))
# for l in range(lmax+1):
#     np.fill_diagonal(hi_full[l], cls_hi[l])
# print(hi_full)

# %%
# def diagonalize_matrices(cl, nfreqs):
#     cl_diag=np.zeros((nfreqs, nfreqs, lmax))
#     for l in range (lmax):
#         #print(f"Diagonalizing matrix {l}")
#         cl_diag[:,:,l]= np.identity(nfreqs)*cl[:,:,l]
#     return cl_diag
# hi_d= diagonalize_matrices(cls_full, nfreqs)

# %%
# cov=glass.cov_from_spectra(cls_hi,lmax=lmax)
# print(cov.shape)

# %%
# Cl_hi=np.zeros_like(cls_hi)
# for i in range(nfreqs-1):
#     Cl_hi[i]= cls_hi[i, :]*rho_HI**2
#     # Cl_hi[i]= cls_hi[i, :]

# %%
def redshift_from_freq(freq_MHz):
    """Convert frequency in MHz to redshift."""
    nu_21 = 1420.40575  # MHz
    return (nu_21 / freq_MHz) - 1
from astropy.cosmology import Planck15 as cosmo

def T_bar(z, Omega_HI=4.02e-4, h=1.0):
    """Compute mean 21cm brightness temperature in mK."""
    H_z = cosmo.H(z).value  # H(z) in km/s/Mpc
    H0 = 70     # H0 in km/s/Mpc
    return 44 * Omega_HI * h * ((1 + z)**2) / (H_z / H0)  # in mK

def calibrate_hi_maps(freqs_MHz, uncalibrated_maps, sq,Omega_HI=4.02e-4, h=1.0):
    """
    Calibrate uncalibrated HI maps to brightness temperature [mK].

    Parameters:
    - freqs_MHz: array-like, list of frequency values in MHz
    - uncalibrated_maps: list or array of maps (shape [nfreqs, npix])
    - Omega_HI: fractional HI density
    - h: reduced Hubble parameter

    Returns:
    - calibrated_maps: array of maps in mK, same shape as input
    - Tbars: array of T̄_b(z) used for each frequency
    """
    freqs_MHz = np.asarray(freqs_MHz)
    uncalibrated_maps = np.asarray(uncalibrated_maps)
    nfreqs = len(freqs_MHz)-1
    
    Tbars = np.zeros(nfreqs)
    calibrated_maps = np.zeros_like(uncalibrated_maps)

    for i, freq in enumerate(freqs_MHz[:-1]):
        z = redshift_from_freq(freq)
        Tbars[i] = T_bar(z, Omega_HI, h)
        calibrated_maps[i] = uncalibrated_maps[i] * Tbars[i]**sq
    # Apply calibration to full Cl_ell^{ij}
    
    # freqs_MHz = np.asarray(freqs_MHz)
    # nfreq = len(freqs_MHz)

    # Tbars = np.zeros(nfreq)
    # for i, freq in enumerate(freqs_MHz):
    #     z = redshift_from_freq(freq)
    #     Tbars[i] = T_bar(z, Omega_HI, h) * 1e-3  # Convert from µK to mK

    # # Apply calibration to full Cl_ell^{ij}
    # lmax = uncalibrated_maps.shape[0] - 1
    # calibrated_maps = np.zeros_like(uncalibrated_maps)

    # for i in range(nfreq):
    #     for j in range(nfreq):
    #         factor = (Tbars[i] * Tbars[j])**(sq/2)  # T_i * T_j if sq=2
    #         calibrated_maps[:, i, j] = uncalibrated_maps[:, i, j] * factor
    

    return calibrated_maps, Tbars

# %% [markdown]
# taking spectra from glass and multiplying them by $\rho_{HI}^2$ and then calibrating to get temperature

# %%
C_hi_2,Temp=calibrate_hi_maps(freqs, cls_hi, 2)
C_hi_3,Temp=calibrate_hi_maps(freqs, cls_hi_i, 2)

# %% [markdown]
# Converting spectra from glass to maps then recalibrating

# %%
old_maps= np.zeros((nfreqs, hp.nside2npix(nside)))
for i in range(nfreqs-1):
    # print ("processing maps %d" % i)
    old_maps[i,:]= hp.synfast(cls_hi_i[i,:], nside)
old_cal,_=calibrate_hi_maps(freqs, old_maps,1)
old_cl=hp.anafast(old_cal[0])

# %%
freqs_old=np.arange(544,1088,step=10) 
print(freqs_old[49])
print(freqs[2])
freqs[0]
# Out:
# 1034
# 1044
# np.int64(1042)

# %%
# plt.plot(old_cl[1:], label='old')
plt.plot(C_hi_2[2,2,:], label='recalibrated')
# plt.plot(C_hi_3[20,:], label='recalibrated cl')
# plt.plot(Cl_hi[45,1:], label='HI')
# plt.plot(cls_hi[49,49,2:], label='from glass')
# plt.plot(cls_full[45,45,1:], label='full')
# plt.yscale('log')
plt.legend()

# %%
np.save('/datadec/cppm/shoaib/SMICA_Paper/data/UHF/hi_cl_mK.npy', C_hi_2)

# %%
C_hi_2.shape
# Out:
# (141, 141, 768)

# %%
map_cl= hp.synfast(C_hi_3[20],nside)
map_cov= hp.synfast(C_hi_2[20,20,:],nside)
hp.mollview(map_cl)
hp.mollview(map_cov)

# %%
hi_maps= np.zeros((nfreqs, hp.nside2npix(nside)))
for i in range(nfreqs-1):
    print ("processing maps %d" % i)
    hi_maps[i,:]= hp.synfast(C_hi_2[i,i,:], nside)
# Out:
# processing maps 0
# processing maps 1
# processing maps 2
# processing maps 3
# processing maps 4
# processing maps 5
# processing maps 6
# processing maps 7
# processing maps 8
# processing maps 9
# processing maps 10
# processing maps 11
# processing maps 12
# processing maps 13
# processing maps 14
# processing maps 15
# processing maps 16
# processing maps 17
# processing maps 18
# processing maps 19
# processing maps 20
# processing maps 21
# processing maps 22
# processing maps 23
# processing maps 24
# processing maps 25
# processing maps 26
# processing maps 27
# processing maps 28
# processing maps 29
# processing maps 30
# processing maps 31
# processing maps 32
# processing maps 33
# processing maps 34
# processing maps 35
# processing maps 36
# processing maps 37
# processing maps 38
# processing maps 39
# processing maps 40
# processing maps 41
# processing maps 42
# processing maps 43
# processing maps 44
# processing maps 45
# processing maps 46
# processing maps 47
# processing maps 48
# processing maps 49
# processing maps 50
# processing maps 51
# processing maps 52
# processing maps 53
# processing maps 54
# processing maps 55
# processing maps 56
# processing maps 57
# processing maps 58
# processing maps 59
# processing maps 60
# processing maps 61
# processing maps 62
# processing maps 63
# processing maps 64
# processing maps 65
# processing maps 66
# processing maps 67
# processing maps 68
# processing maps 69
# processing maps 70
# processing maps 71
# processing maps 72
# processing maps 73
# processing maps 74
# processing maps 75
# processing maps 76
# processing maps 77
# processing maps 78
# processing maps 79
# processing maps 80
# processing maps 81
# processing maps 82
# processing maps 83
# processing maps 84
# processing maps 85
# processing maps 86
# processing maps 87
# processing maps 88
# processing maps 89
# processing maps 90
# processing maps 91
# processing maps 92
# processing maps 93
# processing maps 94
# processing maps 95
# processing maps 96
# processing maps 97
# processing maps 98
# processing maps 99
# processing maps 100
# processing maps 101
# processing maps 102
# processing maps 103
# processing maps 104
# processing maps 105
# processing maps 106
# processing maps 107
# processing maps 108
# processing maps 109
# processing maps 110
# processing maps 111
# processing maps 112
# processing maps 113
# processing maps 114
# processing maps 115
# processing maps 116
# processing maps 117
# processing maps 118
# processing maps 119
# processing maps 120
# processing maps 121
# processing maps 122
# processing maps 123
# processing maps 124
# processing maps 125
# processing maps 126
# processing maps 127
# processing maps 128
# processing maps 129
# processing maps 130
# processing maps 131
# processing maps 132
# processing maps 133
# processing maps 134
# processing maps 135
# processing maps 136
# processing maps 137
# processing maps 138
# processing maps 139

# %%
np.save('/datadec/cppm/shoaib/SMICA_Paper/data/hi_maps_mK_new.npy', hi_maps)
